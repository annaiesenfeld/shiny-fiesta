# %%
import pandas as pd

# %%
protein_df = pd.read_csv('proteins_basic.csv')
protein_df
# Out:
#             Entry        Entry name      Status  \
# 0          Q96NG5       ZN558_HUMAN    reviewed
# 1          Q6ZN19       ZN841_HUMAN    reviewed
# 2          Q9UI25       YP002_HUMAN    reviewed
# 3          Q86XN6       ZN761_HUMAN    reviewed
# 4          A8MUZ8       Z705G_HUMAN    reviewed
# ...           ...               ...         ...
# 79033  A0A804HKA0  A0A804HKA0_HUMAN  unreviewed
# 79034      Q8N9M3      Q8N9M3_HUMAN  unreviewed
# 79035      C9J7J0      C9J7J0_HUMAN  unreviewed
# 79036      K7EMS7      K7EMS7_HUMAN  unreviewed
# 79037      E9PIP2      E9PIP2_HUMAN  unreviewed
#
#                                            Protein names          Gene names  \
# 0                                Zinc finger protein 558              ZNF558
# 1                                Zinc finger protein 841              ZNF841
# 2               Putative uncharacterized protein PRO0461             PRO0461
# ...

# %%
proteins_df= df.drop(['Organism'], axis=1)
proteins_df.rename(columns={"Entry": "Uniprot_ID", "Entry name": "Name"})
# Out:
#        Uniprot_ID              Name      Status  \
# 0          Q96NG5       ZN558_HUMAN    reviewed
# 1          Q6ZN19       ZN841_HUMAN    reviewed
# 2          Q9UI25       YP002_HUMAN    reviewed
# 3          Q86XN6       ZN761_HUMAN    reviewed
# 4          A8MUZ8       Z705G_HUMAN    reviewed
# ...           ...               ...         ...
# 79033  A0A804HKA0  A0A804HKA0_HUMAN  unreviewed
# 79034      Q8N9M3      Q8N9M3_HUMAN  unreviewed
# 79035      C9J7J0      C9J7J0_HUMAN  unreviewed
# 79036      K7EMS7      K7EMS7_HUMAN  unreviewed
# 79037      E9PIP2      E9PIP2_HUMAN  unreviewed
#
#                                            Protein names          Gene names  \
# 0                                Zinc finger protein 558              ZNF558
# 1                                Zinc finger protein 841              ZNF841
# 2               Putative uncharacterized protein PRO0461             PRO0461
# ...
